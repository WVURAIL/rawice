# %%
### import necessary packages ###
import matplotlib.pylab as plt  ##plotting 
from rawice import *            ##all modules from rawice.py
import warnings
import numpy as np
import os

warnings.filterwarnings('ignore')

# %%
## location of raw acq data
notebook_path = os.path.abspath("6.24 1000 fps.ipyn")
folder_path = os.path.join(os.path.dirname(notebook_path), "6.24 1000 fps/")
path = os.path.join(os.path.dirname(notebook_path), "6.24 1000 fps/000000")
## File 000006 is bad for some reason

## load data from file to object 'acq'
acq = raw_acq(path)
#help(raw_acq)
acq.adc_input

#set the input 
tm4_input = [0,0,12]
tm5101_input = [0,0,3]
# Out:
# Loaded raw acq HDF5 file ...

# %%
tm4 = acq.check_input(tm4_input)
tm4.inspect_maser()
#tm4.plot_single_input_diagnostics()
fig, ax = plt.subplots(figsize=(20, 10))
plt.plot(tm4.time_streams[0])
# Out:
# Checking input [0, 0, 12] ...

# %%
tm4_clock = analyse_maser(folder_path, tm4_input)
# Out:
# C:\Users\audre\Documents\WVU REU 2022\6.24 1000 fps\000000
# Loaded raw acq HDF5 file ... .....................................................................] 0/1
# Checking input [0, 0, 12] ...
# Done Computing Delay: ############################################################################] 1/1
#
# DONE reading files and getting delays

# %%
tm4_delays = tm4_clock.plot_delays()

# %%
tm5101 = acq.check_input(tm5101_input)
tm5101.inspect_maser()
#tm5101.plot_single_input_diagnostics()
fig, ax = plt.subplots(figsize=(20, 10))
plt.plot(tm5101.time_streams[1])
# Out:
# Checking input [0, 0, 3] ...

# %%
tm5101_clock = analyse_maser(folder_path, tm5101_input)
# Out:
# C:\Users\audre\Documents\WVU REU 2022\6.24 1000 fps\000000
# Loaded raw acq HDF5 file ... .....................................................................] 0/1
# Checking input [0, 0, 3] ...
# Done Computing Delay: ############################################################################] 1/1
#
# DONE reading files and getting delays

# %%
tm5101_delays = tm5101_clock.plot_delays()

# %%
acq.diagostics()
# Out:
# raw ACQ diagnostics ...
#
# archive_version: 2.4.0
# collection_server: hostname
# git_version_tag: 0.1
# file_name: /home/wvurail/acq/20220624T183725Z_GBOs434/raw_acq/000000
# data_type: ADC snapshot data
# system_user: root
# rawadc_version: 0.1
# Timestamping_warning: Done on file write, may be significantly different from snapshot acquistion time
#
# ctime Timestamp of first raw_adc frame: 2022-06-24T14:38:13.347941
# ctime Timestamp of last raw_adc frame: 2022-06-24T14:42:43.229189
#
# Time between raw_adc captures is either [0.0009984 0.0019968 0.0029952 0.0039936 0.004992  0.0059904 0.0069888
#  0.0079872 0.0089856 0.009984  0.0109824 0.0119808 0.0129792 0.0139776
#  0.014976  0.0159744 0.0169728 0.0179712 0.0189696 0.019968  0.0209664
#  0.0219648 0.0229632 0.0239616 0.02496   0.0259584 0.0269568 0.0279552
#  0.0289536 0.029952  0.0309504 0.0319488 0.0329472 0.0339456 0.034944
#  0.0359424 0.0369408 0.0379392 0.0389376 0.039936  0.0409344 0.0419328
#  0.0429312 0.0439296 0.044928  0.0459264 0.0469248 0.0479232 0.0489216
#  0.04992   0.0509184 0.0519168 0.0529152 0.0539136 0.054912  0.0559104
#  0.0569088 0.0579072 0.0589056 0.059904  0.0609024 0.0619008 0.0628992
#  0.0638976 0.064896  0.0658944 0.0668928 0.0678912 0.0688896 0.069888
#  0.0708864 0.0718848 0.0728832 0.0738816 0.07488   0.0758784 0.0768768
#  0.0778752 0.0788736 0.079872  0.0808704 0.0818688 0.0828672 0.0838656
#  0.084864  0.0858624 0.0868608 0.0878592 0.0888576 0.089856  0.0908544
#  0.0918528 0.0928512 0.0938496 0.094848  0.0968448 0.0988416 0.09984
#  0.1018368] seconds
